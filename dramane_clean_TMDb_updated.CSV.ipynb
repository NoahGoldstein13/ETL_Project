# %%
import pandas as pd

# %%
df = pd.read_csv('Datasets/TMDb_updated.csv')
df.head()
# Out:
#    Unnamed: 0                           title  \
# 0           0                        Ad Astra
# 1           1                       Bloodshot
# 2           2               Bad Boys for Life
# 3           3                         Ant-Man
# 4           4  Percy Jackson: Sea of Monsters
#
#                                             overview original_language  \
# 0  The near future, a time when both hope and har...                en
# 1  After he and his wife are murdered, marine Ray...                en
# 2  Marcus and Mike are forced to confront new thr...                en
# 3  Armed with the astonishing ability to shrink i...                en
# 4  In their quest to confront the ultimate evil, ...                en
#
#    vote_count  vote_average
# 0        2853           5.9
# 1        1349           7.2
# 2        2530           7.1
# 3       13611           7.1
# 4        3542           5.9

# %%
new_df = df[['title','overview','vote_average']]

new_df
# Out:
#                                title  \
# 0                           Ad Astra
# 1                          Bloodshot
# 2                  Bad Boys for Life
# 3                            Ant-Man
# 4     Percy Jackson: Sea of Monsters
# ...                              ...
# 9995                           Cargo
# 9996                  The Good Night
# 9997              The World Is Yours
# 9998             The Grand Seduction
# 9999        Woochi: The Demon Slayer
#
#                                                overview  vote_average
# 0     The near future, a time when both hope and har...           5.9
# 1     After he and his wife are murdered, marine Ray...           7.2
# 2     Marcus and Mike are forced to confront new thr...           7.1
# 3     Armed with the astonishing ability to shrink i...           7.1
# 4     In their quest to confront the ultimate evil, ...           5.9
# ...                                                 ...           ...
# ...

# %%
new_df['title_for_join']=new_df['title'].str.strip()
# Out:
# <ipython-input-29-b6ea9c512e9e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['title_for_join']=new_df['title'].str.strip()

# %%
new_df.sample(20)
# Out:
#                                title  \
# 5134                          Trumbo
# 2762                         Tremors
# 2684           High School Musical 2
# 1669          Das perfekte Geheimnis
# 2345                      The Guilty
# 9642               Wuthering Heights
# 3794  Nutty Professor II: The Klumps
# 7970                          Kazaam
# 1424            A Fistful of Dollars
# 6766                           Mirai
# 4228      Exit Through the Gift Shop
# 493                        Rocketman
# 9922                A Dirty Carnival
# 5005                  Military Wives
# 7714                     The Outpost
# 5319              The Crimson Rivers
# 1550                           Felon
# 1318                    Смотри как я
# 7201                             Don
# 3436         Flight of the Navigator
#
#                                                overview  vote_average  \
# 5134  The career of screenwriter Dalton Trumbo is ha...           7.2
# ...

# %%
chars = "\`*_{}[]()>#+-.,!$:;%'&/?"
for c in chars:
    new_df['title_for_join'] = new_df['title_for_join'].str.replace(c,"")

new_df
# Out:
# <ipython-input-31-7bb9c5993776>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['title_for_join'] = new_df['title_for_join'].str.replace(c,"")
#                                title  \
# 0                           Ad Astra
# 1                          Bloodshot
# 2                  Bad Boys for Life
# 3                            Ant-Man
# 4     Percy Jackson: Sea of Monsters
# ...                              ...
# 9995                           Cargo
# 9996                  The Good Night
# 9997              The World Is Yours
# 9998             The Grand Seduction
# 9999        Woochi: The Demon Slayer
#
#                                                overview  vote_average  \
# ...

# %%
clean_df = new_df.drop_duplicates()
clean_df
# Out:
#                                title  \
# 0                           Ad Astra
# 1                          Bloodshot
# 2                  Bad Boys for Life
# 3                            Ant-Man
# 4     Percy Jackson: Sea of Monsters
# ...                              ...
# 9995                           Cargo
# 9996                  The Good Night
# 9997              The World Is Yours
# 9998             The Grand Seduction
# 9999        Woochi: The Demon Slayer
#
#                                                overview  vote_average  \
# 0     The near future, a time when both hope and har...           5.9
# 1     After he and his wife are murdered, marine Ray...           7.2
# 2     Marcus and Mike are forced to confront new thr...           7.1
# 3     Armed with the astonishing ability to shrink i...           7.1
# 4     In their quest to confront the ultimate evil, ...           5.9
# ...                                                 ...           ...
# ...
