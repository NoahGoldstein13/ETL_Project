# %%
import pandas as pd

# %%
df = pd.read_csv('../Datasets/TMDb_updated.csv')
df.head()
# Out:
#    Unnamed: 0                           title  \
# 0           0                        Ad Astra
# 1           1                       Bloodshot
# 2           2               Bad Boys for Life
# 3           3                         Ant-Man
# 4           4  Percy Jackson: Sea of Monsters
#
#                                             overview original_language  \
# 0  The near future, a time when both hope and har...                en
# 1  After he and his wife are murdered, marine Ray...                en
# 2  Marcus and Mike are forced to confront new thr...                en
# 3  Armed with the astonishing ability to shrink i...                en
# 4  In their quest to confront the ultimate evil, ...                en
#
#    vote_count  vote_average
# 0        2853           5.9
# 1        1349           7.2
# 2        2530           7.1
# 3       13611           7.1
# 4        3542           5.9

# %%
new_df = df[['title','overview','vote_average']]

new_df
# Out:
#                                title  \
# 0                           Ad Astra
# 1                          Bloodshot
# 2                  Bad Boys for Life
# 3                            Ant-Man
# 4     Percy Jackson: Sea of Monsters
# ...                              ...
# 9995                           Cargo
# 9996                  The Good Night
# 9997              The World Is Yours
# 9998             The Grand Seduction
# 9999        Woochi: The Demon Slayer
#
#                                                overview  vote_average
# 0     The near future, a time when both hope and har...           5.9
# 1     After he and his wife are murdered, marine Ray...           7.2
# 2     Marcus and Mike are forced to confront new thr...           7.1
# 3     Armed with the astonishing ability to shrink i...           7.1
# 4     In their quest to confront the ultimate evil, ...           5.9
# ...                                                 ...           ...
# 9995  The story of CARGO takes place on rusty space-...           5.9
# 9996  Gary, a musician, is trapped in an unhappy rel...           5.6
# 9997  To escape his life of crime, a Paris drug deal...           7.1
# 9998  A small fishing village must procure a local d...           6.7
# 9999  Spanning four centuries in Korea, this epic ac...           6.7
#
# [10000 rows x 3 columns]

# %%
new_df['title_for_join']=new_df['title'].str.strip()
new_df['title_for_join']=new_df['title_for_join'].str.replace(" ",'')
new_df['title_for_join']=new_df['title_for_join'].str.lower()
# Out:
# <ipython-input-10-73f2a961771f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['title_for_join']=new_df['title'].str.strip()
# <ipython-input-10-73f2a961771f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['title_for_join']=new_df['title_for_join'].str.replace(" ",'')
# <ipython-input-10-73f2a961771f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['title_for_join']=new_df['title_for_join'].str.lower()

# %%
new_df.sample(20)
# Out:
#                                             title  \
# 2364                               In the Bedroom
# 2140  Austin Powers: International Man of Mystery
# 9516                          Destination Wedding
# 4503                                   True Crime
# 1034                                     Commando
# 8414                               The Full Monty
# 6736                                Julie & Julia
# 3107                  The Haunting in Connecticut
# 5941           The Lion Guard: Return of the Roar
# 7514                     Bedknobs and Broomsticks
# 2816                              Midnight Cowboy
# 5276                                  The Patriot
# 8376         The Disappearance of Haruhi Suzumiya
# 2739                                Tarzan & Jane
# 9486                                 Surveillance
# 9359                        Coal Miner's Daughter
# 3575                          Rab Ne Bana Di Jodi
# 9684                                 Firebreather
# 9439                         Gentlemen of Fortune
# 5738                                      Shaolin
#
#                                                overview  vote_average  \
# 2364  Summertime on the coast of Maine, "In the Bedr...           6.8
# 2140  As a swingin' fashion photographer by day and ...           6.5
# 9516  Ellie Hamilton is helping plan her little sist...           6.7
# 4503  Boozer, skirt chaser, careless father. You cou...           6.5
# 1034  John Matrix, the former leader of a special co...           6.6
# 8414  Sheffield, England. Gaz, a jobless steelworker...           7.0
# 6736  Julia Child and Julie Powell – both of whom wr...           6.6
# 3107  When the Campbell family moves to upstate Conn...           6.1
# 5941  Set in the African savannah, the film follows ...           6.0
# 7514  Three children evacuated from London during Wo...           7.0
# 2816  Joe Buck is a wide-eyed hustler from Texas hop...           7.6
# 5276  A deadly virus threatens to wipe out an entire...           4.5
# 8376  It is mid-december, and SOS Brigade chief Haru...           7.9
# 2739  Sprightly amusement for kids of all ages, Disn...           5.8
# 9486  An FBI agent tracks a serial killer with the h...           6.0
# 9359  Biography of Loretta Lynn, a country and weste...           7.2
# 3575  A lonely 40-ish man, likely to remain a bachel...           6.7
# 9684  Firebreather is a CGI animated made-for-TV fil...           6.4
# 9439  A kindergarten director Troshkin is a dead rin...           7.8
# 5738  China is plunged into strife as feuding warlor...           6.6
#
#                               title_for_join
# 2364                            inthebedroom
# 2140  austinpowers:internationalmanofmystery
# 9516                      destinationwedding
# 4503                               truecrime
# 1034                                commando
# 8414                            thefullmonty
# 6736                             julie&julia
# 3107                thehauntinginconnecticut
# 5941            thelionguard:returnoftheroar
# 7514                  bedknobsandbroomsticks
# 2816                          midnightcowboy
# 5276                              thepatriot
# 8376        thedisappearanceofharuhisuzumiya
# 2739                             tarzan&jane
# 9486                            surveillance
# 9359                     coalminer'sdaughter
# 3575                         rabnebanadijodi
# 9684                            firebreather
# 9439                      gentlemenoffortune
# 5738                                 shaolin

# %%
chars = "\`*_{}[]()>#+-.,!$:;%'&/?"
for c in chars:
    new_df['title_for_join'] = new_df['title_for_join'].str.replace(c,"")

new_df
# Out:
# <ipython-input-12-7bb9c5993776>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['title_for_join'] = new_df['title_for_join'].str.replace(c,"")
#                                title  \
# 0                           Ad Astra
# 1                          Bloodshot
# 2                  Bad Boys for Life
# 3                            Ant-Man
# 4     Percy Jackson: Sea of Monsters
# ...                              ...
# 9995                           Cargo
# 9996                  The Good Night
# 9997              The World Is Yours
# 9998             The Grand Seduction
# 9999        Woochi: The Demon Slayer
#
#                                                overview  vote_average  \
# 0     The near future, a time when both hope and har...           5.9
# 1     After he and his wife are murdered, marine Ray...           7.2
# 2     Marcus and Mike are forced to confront new thr...           7.1
# 3     Armed with the astonishing ability to shrink i...           7.1
# 4     In their quest to confront the ultimate evil, ...           5.9
# ...                                                 ...           ...
# 9995  The story of CARGO takes place on rusty space-...           5.9
# 9996  Gary, a musician, is trapped in an unhappy rel...           5.6
# 9997  To escape his life of crime, a Paris drug deal...           7.1
# 9998  A small fishing village must procure a local d...           6.7
# 9999  Spanning four centuries in Korea, this epic ac...           6.7
#
#                  title_for_join
# 0                       adastra
# 1                     bloodshot
# 2                badboysforlife
# 3                        antman
# 4     percyjacksonseaofmonsters
# ...                         ...
# 9995                      cargo
# 9996               thegoodnight
# 9997            theworldisyours
# 9998          thegrandseduction
# 9999       woochithedemonslayer
#
# [10000 rows x 4 columns]

# %%
clean_df = new_df.drop_duplicates()
clean_df
# Out:
#                                title  \
# 0                           Ad Astra
# 1                          Bloodshot
# 2                  Bad Boys for Life
# 3                            Ant-Man
# 4     Percy Jackson: Sea of Monsters
# ...                              ...
# 9995                           Cargo
# 9996                  The Good Night
# 9997              The World Is Yours
# 9998             The Grand Seduction
# 9999        Woochi: The Demon Slayer
#
#                                                overview  vote_average  \
# 0     The near future, a time when both hope and har...           5.9
# 1     After he and his wife are murdered, marine Ray...           7.2
# 2     Marcus and Mike are forced to confront new thr...           7.1
# 3     Armed with the astonishing ability to shrink i...           7.1
# 4     In their quest to confront the ultimate evil, ...           5.9
# ...                                                 ...           ...
# 9995  The story of CARGO takes place on rusty space-...           5.9
# 9996  Gary, a musician, is trapped in an unhappy rel...           5.6
# 9997  To escape his life of crime, a Paris drug deal...           7.1
# 9998  A small fishing village must procure a local d...           6.7
# 9999  Spanning four centuries in Korea, this epic ac...           6.7
#
#                  title_for_join
# 0                       adastra
# 1                     bloodshot
# 2                badboysforlife
# 3                        antman
# 4     percyjacksonseaofmonsters
# ...                         ...
# 9995                      cargo
# 9996               thegoodnight
# 9997            theworldisyours
# 9998          thegrandseduction
# 9999       woochithedemonslayer
#
# [10000 rows x 4 columns]

# %%
clean_df.to_csv(r'../clean_datasets/clean_TMDb_data.csv', index = False)
